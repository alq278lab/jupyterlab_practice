# %% [markdown]
# <p style='background:aqua'>We are currently working in the following directory:</p>

# %%
# !pwd
# Out:
# /c/Users/aquiapo/Downloads/datascience/assgn7/student/jupyterlab_practice

# %% [markdown]
# <p style='background:aqua'>To time how long it takes to run a Python cell, we could use the timeit command inside a cell as is shown below: Followed by the proper use of the timeit command to time the following loop:</p>

# %%
# %%timeit 
for i in range(10):
  i**2
# Out:
# 522 ns ± 13.8 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# !jupyter nbconvert --to html question12.ipynb
# Out:
# [NbConvertApp] WARNING | Config option `kernel_spec_manager_class` not recognized by `NbConvertApp`.
# [NbConvertApp] Converting notebook question12.ipynb to html
# [NbConvertApp] Writing 272719 bytes to question12.html
